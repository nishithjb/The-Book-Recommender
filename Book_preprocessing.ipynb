# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('book_data.csv')
data.head()
# Out:
#                                         book_authors  \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling|Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                    Stephenie Meyer
#
#                                            book_desc  \
# 0  Winning will make you famous. Losing means cer...
# 1  There is a door at the end of a silent corrido...
# 2  The unforgettable novel of a childhood in a sl...
# 3  «È cosa ormai risaputa che a uno scapolo in po...
# 4  About three things I was absolutely positive.F...
#
#                          book_edition book_format    book_isbn book_pages  \
# 0                                 NaN   Hardcover  9.78044E+12  374 pages
# 1                          US Edition   Paperback  9.78044E+12  870 pages
# 2                    50th Anniversary   Paperback  9.78006E+12  324 pages
# ...

# %%
data.columns
# Out:
# Index(['book_authors', 'book_desc', 'book_edition', 'book_format', 'book_isbn',
#        'book_pages', 'book_rating', 'book_rating_count', 'book_review_count',
#        'book_title', 'genres', 'image_url'],
#       dtype='object')

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
book = data.loc[:,['book_authors','book_title','book_rating','book_rating_count','book_review_count','genres']]

# %%
book.describe
# Out:
# <bound method NDFrame.describe of                                             book_authors  \
# 0                                        Suzanne Collins
# 1                             J.K. Rowling|Mary GrandPré
# 2                                             Harper Lee
# 3      Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                        Stephenie Meyer
# 5                                           Markus Zusak
# 6                              C.S. Lewis|Pauline Baynes
# 7                                          George Orwell
# 8                                      Margaret Mitchell
# 9                                         J.R.R. Tolkien
# 10                                            John Green
# 11                                         Douglas Adams
# 12                                      Shel Silverstein
# 13     Emily Brontë|Richard J. Dunn|David Timson|Char...
# 14                                             Dan Brown
# ...

# %%
book['genres'].isnull().count
# Out:
# <bound method Series.count of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 54271    False
# 54272    False
# 54273    False
# 54274    False
# 54275    False
# 54276    False
# 54277    False
# 54278    False
# 54279    False
# 54280    False
# 54281    False
# 54282    False
# 54283    False
# 54284    False
# 54285    False
# 54286    False
# 54287    False
# 54288    False
# 54289    False
# 54290     True
# 54291    False
# 54292    False
# 54293    False
# 54294    False
# 54295    False
# 54296    False
# ...

# %%
book['genres'] = book['genres'].replace(np.nan, "unknown")

# %%
sns.heatmap(book.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
book.head()
# Out:
#                                         book_authors  \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen Anna Quindlen Mrs. Oliphant George...
# 4                                    Stephenie Meyer
#
#                                   book_title  \
# 0                           the hunger games
# 1  harry potter and the order of the phoenix
# 2                      to kill a mockingbird
# 3                        pride and prejudice
# 4                                   twilight
#
#                                               genres
# 0  Young Adult Fiction Science Fiction Dystopia F...
# 1                        Fantasy Young Adult Fiction
# 2  Classics Fiction Historical Historical Fiction...
# 3                           Classics Fiction Romance
# 4  Young Adult Fantasy Romance Paranormal Vampire...

# %%
book['genres'] = book['genres'].str.replace('|', ' ')

# %%
book.head()
# Out:
#                                         book_authors  \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen Anna Quindlen Mrs. Oliphant George...
# 4                                    Stephenie Meyer
#
#                                   book_title  book_rating  book_rating_count  \
# 0                           the hunger games         4.33            5519135
# 1  harry potter and the order of the phoenix         4.48            2041594
# 2                      to kill a mockingbird         4.27            3745197
# 3                        pride and prejudice         4.25            2453620
# 4                                   twilight         3.58            4281268
#
#    book_review_count                                             genres
# 0             160706  Young Adult Fiction Science Fiction Dystopia F...
# ...

# %%
book['book_title'] = data['book_title'].str.lower()

# %%
book.head()
# Out:
#                                         book_authors  \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling|Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                    Stephenie Meyer
#
#                                   book_title  book_rating  book_rating_count  \
# 0                           the hunger games         4.33            5519135
# 1  harry potter and the order of the phoenix         4.48            2041594
# 2                      to kill a mockingbird         4.27            3745197
# 3                        pride and prejudice         4.25            2453620
# 4                                   twilight         3.58            4281268
#
#    book_review_count                                             genres
# 0             160706  Young Adult|Fiction|Science Fiction|Dystopia|F...
# ...

# %%
book['book_authors']= book['book_authors'].str.replace("|"," ")

# %%
book.head()
# Out:
#                                         book_authors  \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen Anna Quindlen Mrs. Oliphant George...
# 4                                    Stephenie Meyer
#
#                                   book_title  book_rating  book_rating_count  \
# 0                           the hunger games         4.33            5519135
# 1  harry potter and the order of the phoenix         4.48            2041594
# 2                      to kill a mockingbird         4.27            3745197
# 3                        pride and prejudice         4.25            2453620
# 4                                   twilight         3.58            4281268
#
#    book_review_count                                             genres
# 0             160706  Young Adult Fiction Science Fiction Dystopia F...
# ...

# %%
book.to_csv('book.csv',index=False)

# %%
data = book[:1000]

# %%
data.to_csv('books.csv',index=False)
